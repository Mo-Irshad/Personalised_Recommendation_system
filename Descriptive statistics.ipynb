# %%
import pandas as pd

# %%
df = pd.read_excel('Cleaned_dataset.xlsx')

# %%
df.head()
# Out:
#    Bill Date    Cust cid          Outlet Name         MAINCATEGORY  \
# 0 2025-03-14  1N60006307  FRESH2DAY - KILPAUK  FRUITS & VEGETABLES
# 1 2025-03-14  1N60006307  FRESH2DAY - KILPAUK  FRUITS & VEGETABLES
# 2 2025-03-14  1N60006307  FRESH2DAY - KILPAUK  FRUITS & VEGETABLES
# 3 2025-03-14  1N60006307  FRESH2DAY - KILPAUK              Staples
# 4 2025-03-21  1N60006307  FRESH2DAY - KILPAUK  FRUITS & VEGETABLES
#
#          SUBCATEGORY     BRANDS          CATEGORY  Item Code  \
# 0     Regular Fruits        F2D      FRESH FRUITS      156.0
# 1     Regular Fruits        F2D      FRESH FRUITS      156.0
# 2  Herbs & Seasoning        F2D  FRESH VEGETABLES       88.0
# 3       Whole Spices  FRESH2DAY            Masala     2684.0
# 4     Regular Fruits        F2D      FRESH FRUITS      153.0
#
#              Item Name   Qty Item Rate  Total Amt     segment
# 0  BANANA KARPOORAVALI  0.60        80      48.24  High Value
# 1  BANANA KARPOORAVALI  0.09        80       6.96  High Value
# ...

# %%
df_stat= df.groupby(['segment','CATEGORY'])['Total Amt'].agg(SUM = 'sum')

# %%
df_stat.sort_values(by = 'SUM', ascending = False).head(10)
# Out:
#                                                  SUM
# segment      CATEGORY
# High Value   FRESH FRUITS                10375247.54
#              FRESH VEGETABLES             5147831.58
# Medium Value FRESH FRUITS                 2101996.22
# High Value   Exotic Fruits & Vegetables    848069.05
#              Chilled Dairy                 706584.01
# Medium Value FRESH VEGETABLES              568360.67
# High Value   Fresh Fruits                  494252.06
#              Foodgrain                     475049.04
#              Ready Foods                   429584.99
#              Instant                       199561.43
